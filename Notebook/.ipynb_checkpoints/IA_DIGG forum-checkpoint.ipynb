# %% [markdown]
# # DIGG forum rapport
#
# * [#1482](https://github.com/salgo60/DIGG-skuggbacklog/issues/1482)
# * Denna Notebook [IA DIGG forum](https://github.com/salgo60/DIGG-skuggbacklog/blob/master/Notebook/IA_DIGG%20forum.ipynb)
#    * se även Notebook [1478 DIGG forum](https://github.com/salgo60/DIGG-skuggbacklog/blob/master/Notebook/1478%20DIGG%20forum.ipynb)

# %%
import time

from datetime import datetime

now = datetime.now()
timestamp = now.timestamp()

start_time = time.time()
print("Start:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Start: 2025-12-08 09:15:09

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (10, 5)

# 1. läs in
df = pd.read_json("forum_data.json")

# Kolla snabbt
df.head(), df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4063 entries, 0 to 4062
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tid              4063 non-null   int64
#  1   cid              4063 non-null   int64
#  2   slug             4063 non-null   object
#  3   topic_title      4063 non-null   object
#  4   topic_timestamp  4063 non-null   object
#  5   pid              4063 non-null   int64
#  6   post_index       4063 non-null   int64
#  7   post_timestamp   4063 non-null   object
#  8   uid              4063 non-null   int64
#  9   content_html     4063 non-null   object
#  10  content_len      4063 non-null   int64
#  11  post_date        4063 non-null   int64
#  12  username         3225 non-null   object
#  13  username_norm    4063 non-null   object
#  14  is_digg          4063 non-null   bool
#  15  post_month       4063 non-null   object
# dtypes: bool(1), int64(7), object(8)
# memory usage: 480.2+ KB
# (    tid  cid                                               slug  \
#  0   282   23  282/hjälp-nosad-och-dataportalens-communityfor...
#  1  1059   23  1059/dataportal-se-har-stöd-för-sparql-queries...
#  2  1059   23  1059/dataportal-se-har-stöd-för-sparql-queries...
#  3  1059   23  1059/dataportal-se-har-stöd-för-sparql-queries...
#  4  1059   23  1059/dataportal-se-har-stöd-för-sparql-queries...
#
#                                           topic_title  \
#  0  Hjälp NOSAD och dataportalens communityforum a...
#  1  Dataportal.se har stöd för Sparql-queries, vis...
#  2  Dataportal.se har stöd för Sparql-queries, vis...
#  3  Dataportal.se har stöd för Sparql-queries, vis...
#  4  Dataportal.se har stöd för Sparql-queries, vis...
#
#              topic_timestamp   pid  post_index            post_timestamp   uid  \
#  0  2022-01-11T17:30:39.030Z  1213           0  2022-01-11T17:30:39.030Z    62
#  1  2025-10-06T09:12:42.687Z  5304           0  2025-10-06T09:12:42.687Z   127
#  2  2025-10-06T09:12:42.687Z  5305           1  2025-10-06T10:06:41.301Z  1802
#  3  2025-10-06T09:12:42.687Z  5307           2  2025-10-06T12:31:26.643Z   127
#  4  2025-10-06T09:12:42.687Z  5309           3  2025-10-06T13:16:28.870Z  1802
#
#                                          content_html  content_len  \
#  0  <p dir="auto">11 januari hade NOSAD (Network o...         5170
#  1  <p dir="auto">Hej tänkte bara meddela att en f...         4756
#  2  <p dir="auto">Trevligt man kan undra varför de...          557
#  3  <p dir="auto"><a class="plugin-mentions-user p...         2021
#  4  <p dir="auto">SPARQL det är bara att vibe prog...         1899
#
#         post_date       username  username_norm  is_digg post_month
#  0  1641922239030  Maria_Dalhage  maria_dalhage     True    2022-01
#  1  1759741962687    tomasmonsen    tomasmonsen    False    2025-10
#  2  1759745201301   Magnus Sälgö   magnus sälgö    False    2025-10
#  3  1759753886643    tomasmonsen    tomasmonsen    False    2025-10
#  4  1759756588870   Magnus Sälgö   magnus sälgö    False    2025-10  ,
#  None)

# %%
df.head(3)
# Out:
#     tid  cid                                               slug  \
# 0   282   23  282/hjälp-nosad-och-dataportalens-communityfor...
# 1  1059   23  1059/dataportal-se-har-stöd-för-sparql-queries...
# 2  1059   23  1059/dataportal-se-har-stöd-för-sparql-queries...
#
#                                          topic_title  \
# 0  Hjälp NOSAD och dataportalens communityforum a...
# 1  Dataportal.se har stöd för Sparql-queries, vis...
# 2  Dataportal.se har stöd för Sparql-queries, vis...
#
#             topic_timestamp   pid  post_index            post_timestamp   uid  \
# 0  2022-01-11T17:30:39.030Z  1213           0  2022-01-11T17:30:39.030Z    62
# 1  2025-10-06T09:12:42.687Z  5304           0  2025-10-06T09:12:42.687Z   127
# 2  2025-10-06T09:12:42.687Z  5305           1  2025-10-06T10:06:41.301Z  1802
#
#                                         content_html  content_len  \
# 0  <p dir="auto">11 januari hade NOSAD (Network o...         5170
# 1  <p dir="auto">Hej tänkte bara meddela att en f...         4756
# 2  <p dir="auto">Trevligt man kan undra varför de...          557
#
#        post_date       username  username_norm  is_digg post_month
# 0  1641922239030  Maria_Dalhage  maria_dalhage     True    2022-01
# 1  1759741962687    tomasmonsen    tomasmonsen    False    2025-10
# 2  1759745201301   Magnus Sälgö   magnus sälgö    False    2025-10

# %%
import requests
import time
from requests.exceptions import RequestException

BASE_URL = "https://community.dataportal.se/topic/"
SAVE_API = "https://web.archive.org/save/"
HEADERS = {"User-Agent": "ArchiveBot/1.0 (salgo60@msn.com)"}

session = requests.Session()
session.headers.update(HEADERS)


def resolve_final_url(url):
    """Follow redirects and return the final URL (with slug if present)."""
    try:
        r = session.get(url, timeout=20, allow_redirects=True)
        if r.status_code == 200:
            return r.url
        print(f"  ⚠ Cannot load {url}: {r.status_code}")
        return None
    except RequestException as e:
        print(f"  ⚠ Error resolving {url}: {e}")
        return None

def url_exists(url, retries=3):
    """Return True only if the source URL returns 200."""
    for attempt in range(1, retries + 1):
        try:
            r = session.head(url, timeout=20, allow_redirects=True)
            if r.status_code == 200:
                return True
            elif r.status_code >= 400:
                print(f"  ⚠ Source returned {r.status_code} → skip")
                return False
        except RequestException as e:
            print(f"  ⚠ HEAD error: {e} (attempt {attempt})")
            time.sleep(2 * attempt)

    print("  ❌ Could not verify URL → skip")
    return False


def archive_url(url, max_retries=5):
    """Try archiving a URL with retries and exponential backoff."""
    delay = 20

    for attempt in range(1, max_retries + 1):
        try:
            print(f"  Attempt {attempt}: {url}")

            r = session.get(
                SAVE_API + url,
                timeout=60,
                allow_redirects=True
            )

            if r.status_code in (200, 301, 302):
                saved = r.headers.get("Content-Location")
                if saved:
                    print("    ✔ Archived at:", "https://web.archive.org" + saved)
                else:
                    print("    ✔ Archived (no location returned)")
                return True

            print(f"    ✖ Status {r.status_code}, retrying...")

        except RequestException as e:
            print(f"    ✖ Error: {e}, retrying...")

        time.sleep(delay)
        delay *= 2

    print("    ❌ Failed after all retries:", url)
    return False


# ---- MAIN LOOP ----
df_sorted = df.sort_values("pid", ascending=False)
df_sorted = df_sorted[df_sorted["pid"] <= 1075]

for row in df_sorted.itertuples(index=False):
    pid = row.pid
    base_url = f"{BASE_URL}{pid}"

    print(f"Resolving {base_url} …")
    final_url = resolve_final_url(base_url)

    if not final_url:
        continue

    print("  → Final URL:", final_url)

    if not url_exists(final_url):
        continue

    print(f"Saving {final_url} …")
    archive_url(final_url)

    time.sleep(5)
# Out:
# Resolving https://community.dataportal.se/topic/1070 …
#   → Final URL: https://community.dataportal.se/topic/1070/ai-i-staten-lo-sning-eller-kaos/1
# Saving https://community.dataportal.se/topic/1070/ai-i-staten-lo-sning-eller-kaos/1 …
#   Attempt 1: https://community.dataportal.se/topic/1070/ai-i-staten-lo-sning-eller-kaos/1
#     ✔ Archived (no location returned)
# Resolving https://community.dataportal.se/topic/1068 …
#   → Final URL: https://community.dataportal.se/topic/1068/lagar-som-bromsar-framtiden-sfs-2007-755-kr%C3%A4ver-faxnummer/1
# Saving https://community.dataportal.se/topic/1068/lagar-som-bromsar-framtiden-sfs-2007-755-kr%C3%A4ver-faxnummer/1 …
#   Attempt 1: https://community.dataportal.se/topic/1068/lagar-som-bromsar-framtiden-sfs-2007-755-kr%C3%A4ver-faxnummer/1
#     ✔ Archived (no location returned)
# Resolving https://community.dataportal.se/topic/1067 …
#   → Final URL: https://community.dataportal.se/topic/1067/mot-ett-sammanh%C3%A4ngande-datadrivet-politik-ekosystem-i-sverige/1
# Saving https://community.dataportal.se/topic/1067/mot-ett-sammanh%C3%A4ngande-datadrivet-politik-ekosystem-i-sverige/1 …
#   Attempt 1: https://community.dataportal.se/topic/1067/mot-ett-sammanh%C3%A4ngande-datadrivet-politik-ekosystem-i-sverige/1
#     ✔ Archived (no location returned)
# Resolving https://community.dataportal.se/topic/1066 …
#   → Final URL: https://community.dataportal.se/topic/1066/referensdata/1
# Saving https://community.dataportal.se/topic/1066/referensdata/1 …
#   Attempt 1: https://community.dataportal.se/topic/1066/referensdata/1
#     ✖ Error: HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=60), retrying...
#   Attempt 2: https://community.dataportal.se/topic/1066/referensdata/1
#     ✔ Archived (no location returned)
# Resolving https://community.dataportal.se/topic/1065 …
#   → Final URL: https://community.dataportal.se/topic/1065/tillg%C3%A4nglighet-f%C3%B6r-data-i-eus-genomf%C3%B6randef%C3%B6rordning-hvd-fr%C3%A5n-kommuner/1
# Saving https://community.dataportal.se/topic/1065/tillg%C3%A4nglighet-f%C3%B6r-data-i-eus-genomf%C3%B6randef%C3%B6rordning-hvd-fr%C3%A5n-kommuner/1 …
#   Attempt 1: https://community.dataportal.se/topic/1065/tillg%C3%A4nglighet-f%C3%B6r-data-i-eus-genomf%C3%B6randef%C3%B6rordning-hvd-fr%C3%A5n-kommuner/1
#     ✖ Error: HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=60), retrying...
#   Attempt 2: https://community.dataportal.se/topic/1065/tillg%C3%A4nglighet-f%C3%B6r-data-i-eus-genomf%C3%B6randef%C3%B6rordning-hvd-fr%C3%A5n-kommuner/1
#     ✔ Archived (no location returned)
# Resolving https://community.dataportal.se/topic/1064 …
#   → Final URL: https://community.dataportal.se/topic/1064/informationsmeddelande-apierna-jobad-links-jobad-enrichments-och-jobstream/1
# Saving https://community.dataportal.se/topic/1064/informationsmeddelande-apierna-jobad-links-jobad-enrichments-och-jobstream/1 …
#   Attempt 1: https://community.dataportal.se/topic/1064/informationsmeddelande-apierna-jobad-links-jobad-enrichments-och-jobstream/1
#     ✖ Error: HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=60), retrying...
#   Attempt 2: https://community.dataportal.se/topic/
1
#     ✔ Archived (no location returned)
# Resolving https://community.dataportal.se/topic/1051 …
#   → Final URL: https://community.dataportal.se/topic/1051/nu-%C3%A4r-det-semesterst%C3%A4ngt-p%C3%A5-communityt/1
# Saving https://community.dataportal.se/topic/1051/nu-%C3%A4r-det-semesterst%C3%A4ngt-p%C3%A5-communityt/1 …
#   Attempt 1: https://community.dataportal.se/topic/1051/nu-%C3%A4r-det-semesterst%C3%A4ngt-p%C3%A5-communityt/1
#     ✔ Archived (no location returned)
# Resolving https://community.dataportal.se/topic/1050 …
#   → Final URL: https://community.dataportal.se/topic/1050/snart-g%C3%A5r-vi-p%C3%A5-digg-p%C3%A5-semester/1
# Saving https://community.dataportal.se/topic/1050/snart-g%C3%A5r-vi-p%C3%A5-digg-p%C3%A5-semester/1 …
#   Attempt 1: https://community.dataportal.se/topic/1050/snart-g%C3%A5r-vi-p%C3%A5-digg-p%C3%A5-semester/1
#     ✔ Archived (no location returned)
# Resolving https://community.dataportal.se/topic/1049 …
#   → Final URL: https://community.dataportal.se/topic/1049/nyttan-med-%C3%B6ppet-data-hur-blev-det/1
# Saving https://community.dataportal.se/topic/1049/nyttan-med-%C3%B6ppet-data-hur-blev-det/1 …
#   Attempt 1: https://community.dataportal.se/topic/1049/nyttan-med-%C3%B6ppet-data-hur-blev-det/1
#     ✖ Error: HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=60), retrying...
#   Attempt 2: https://community.dataportal.se/topic/1049/nyttan-med-%C3%B6ppet-data-hur-blev-det/1
#     ✔ Archived (no location returned)
# Resolving https://community.dataportal.se/topic/1048 …
#   → Final URL: https://community.dataportal.se/topic/1048/nosad-nyhetsbrev-juni-2025/1
# Saving https://community.dataportal.se/topic/1048/nosad-nyhetsbrev-juni-2025/1 …
#   Attempt 1: https://community.dataportal.se/topic/1048/nosad-nyhetsbrev-juni-2025/1
#     ✖ Error: HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=60), retrying...
#   Attempt 2: https://community.dataportal.se/topic/1048/nosad-nyhetsbrev-juni-2025/1
#     ✔ Archived (no location returned)
# Resolving https://community.dataportal.se/topic/1047 …
#   → Final URL: https://community.dataportal.se/topic/1047/flyttat-inl%C3%A4gg-om-f%C3%B6reslagen-sammanslagning-digg-och-pts/1
# Saving https://community.dataportal.se/topic/1047/flyttat-inl%C3%A4gg-om-f%C3%B6reslagen-sammanslagning-digg-och-pts/1 …
#   Attempt 1: https://community.dataportal.se/topic/1047/flyttat-inl%C3%A4gg-om-f%C3%B6reslagen-sammanslagning-digg-och-pts/1
#     ✔ Archived (no location returned)
# Resolving https://community.dataportal.se/topic/1046 …
#   → Final URL: https://community.dataportal.se/topic/1046/bug-katalogen-anger-ingen-titel-angiven-f%C3%B6r-distributioner-det-%C3%A4r-det-visst-det/1
# Saving https://community.dataportal.se/topic/1046/bug-katalogen-anger-ingen-titel-angiven-f%C3%B6r-distributioner-det-%C3%A4r-det-visst-det/1 …
#   Attempt 1: https://community.dataportal.se/topic/1046/bug-katalogen-anger-ingen-titel-angiven-f%C3%B6r-distributioner-det-%C3%A4r-det-visst-det/1
#     ✖ Error: HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=60), retrying...
#   Attempt 2: https://community.dataportal.se/topic/1046/bug-katalogen-anger-ingen-titel-angiven-f%C3%B6r-distributioner-det-%C3%A4r-det-visst-det/1

# %%
 # End timer and calculate duration
end_time = time.time()
elapsed_time = end_time - start_time# Bygg audit-lager för den här etappen

# Print current date and total time
print("Date:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
minutes, seconds = divmod(elapsed_time, 60)
print("Total time elapsed: {:02.0f} minutes {:05.2f} seconds".format(minutes, seconds))
