# %% [markdown]
# ### Checka länkar
# DIGG går i graven och osökerhet finns hur denna process fungerar
# * [#1467](https://github.com/salgo60/DIGG-skuggbacklog/issues/1467)
# * Notebook [DIGG_1467_linkroot](https://github.com/salgo60/DIGG-skuggbacklog/tree/master/Notebook/DIGG_1467_linkroot.ipynb)
#
#
# URL
# https://www.digg.se/

# %%
import time

from datetime import datetime

now = datetime.now()
timestamp = now.timestamp()

start_time = time.time()
print("Start:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Start: 2025-11-29 09:51:25

# %%
def read_domains(file_path):
    print(f"[DEBUG] Reading domains from: {file_path}")
    df = pd.read_csv(file_path, header=0)   # <- skip header row
    domains_list = df.iloc[:, 0].dropna().unique().tolist()
    print(f"[DEBUG] Found {len(domains_list)} domains.")
    return domains_list

# %%
import requests

def fetch_sitematrix_df():
    url = "https://meta.wikimedia.org/w/api.php"
    params = {
        "action": "sitematrix",
        "format": "json"
    }
    headers = {
        "User-Agent": "salgo60-language-fetcher/1.0 (salgo60@msn.com)"
    }

    print("[DEBUG] Fetching sitematrix…")
    r = requests.get(url, params=params, headers=headers)
    r.raise_for_status()

    if "application/json" not in r.headers.get("Content-Type", ""):
        raise ValueError("Server returned non-JSON response")

    data = r.json()["sitematrix"]

    rows = []

    # --- language-specific sites ---
    for key, lang_block in data.items():
        if not key.isdigit():
            continue  # skip "count", "specials"

        lang_code = lang_block.get("code")
        lang_name = lang_block.get("name")

        for site in lang_block.get("site", []):
            rows.append({
                "lang_code": lang_code,
                "lang_name": lang_name,
                "project": site.get("project"),
                "url": site.get("url"),
                "dbname": site.get("dbname"),
                "site_name": site.get("sitename"),
                "closed": site.get("closed", False)
            })

    # --- special wikis (Wikidata, Commons, Meta, etc.) ---
    for site in data.get("specials", []):
        rows.append({
            "lang_code": "special",
            "lang_name": "special",
            "project": site.get("project"),
            "url": site.get("url"),
            "dbname": site.get("dbname"),
            "site_name": site.get("sitename"),
            "closed": site.get("closed", False)
        })

    return pd.DataFrame(rows)

# %%
import requests
import pandas as pd


HEADERS = {
    "User-Agent": "salgo60-language-fetcher/2.0 (https://github.com/salgo60)"
}


df_lang_fetch = fetch_sitematrix_df()
df_lang_fetch["closed"] = df_lang_fetch["closed"].fillna(False).astype(bool)

df_lang_fetch.head()
# Out:
# [DEBUG] Fetching sitematrix…
#   lang_code lang_name project                        url        dbname  \
# 0        aa  Qafár af    None   https://aa.wikipedia.org        aawiki
# 1        aa  Qafár af    None  https://aa.wiktionary.org  aawiktionary
# 2        aa  Qafár af    None   https://aa.wikibooks.org   aawikibooks
# 3        ab    аԥсшәа    None   https://ab.wikipedia.org        abwiki
# 4        ab    аԥсшәа    None  https://ab.wiktionary.org  abwiktionary
#
#     site_name  closed
# 0   Wikipedia   False
# 1  Wiktionary   False
# 2   Wikibooks   False
# 3  Авикипедиа   False
# 4  Wiktionary   False

# %%
df_lang_fetch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1063 entries, 0 to 1062
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lang_code  1063 non-null   object
#  1   lang_name  1060 non-null   object
#  2   project    0 non-null      object
#  3   url        1063 non-null   object
#  4   dbname     1063 non-null   object
#  5   site_name  1063 non-null   object
#  6   closed     1063 non-null   bool
# dtypes: bool(1), object(6)
# memory usage: 51.0+ KB

# %%
df_wiki = df_lang_fetch[df_lang_fetch["site_name"] == "Wikipedia"] 
df_wiki.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 207 entries, 0 to 1061
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lang_code  207 non-null    object
#  1   lang_name  206 non-null    object
#  2   project    0 non-null      object
#  3   url        207 non-null    object
#  4   dbname     207 non-null    object
#  5   site_name  207 non-null    object
#  6   closed     207 non-null    bool
# dtypes: bool(1), object(6)
# memory usage: 11.5+ KB

# %%
df_wiki.head()
# Out:
#    lang_code  lang_name project                        url   dbname  \
# 0         aa   Qafár af    None   https://aa.wikipedia.org   aawiki
# 5        ace       Acèh    None  https://ace.wikipedia.org  acewiki
# 7         af  Afrikaans    None   https://af.wikipedia.org   afwiki
# 11        ak       None    None   https://ak.wikipedia.org   akwiki
# 18       ami    Pangcah    None  https://ami.wikipedia.org  amiwiki
#
#     site_name  closed
# 0   Wikipedia   False
# 5   Wikipedia   False
# 7   Wikipedia   False
# 11  Wikipedia   False
# 18  Wikipedia   False

# %%
len(df_wiki)
# Out:
# 207

# %%
import os

# Get the current working directory
current_directory = os.getcwd()
print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: /Users/salgo/Documents/GitHub/DIGG-skuggbacklog/Notebook

# %%
# -----------------------------------------------------------
# Fetch exturlusage entries for one lang/domain
# -----------------------------------------------------------
def fetch_exturlusage(lang, domain):
    base = f"https://{lang}.wikipedia.org/w/api.php"
    params = {
        "action": "query",
        "format": "json",
        "list": "exturlusage",
        "euquery": domain,
        "eulimit": "max"
    }
    while True:
        r = session.get(base, params=params, timeout=10)
        try:
            data = r.json()
        except ValueError:
            print(f"[WARN] {lang}: JSON decode failed")
            break

        for item in data.get("query", {}).get("exturlusage", []):
            yield {
                "lang": lang,
                "page_title": item.get("title"),
                "url": item.get("url"),
                "wiki_link": f"https://{lang}.wikipedia.org/wiki/{item.get('title').replace(' ', '_')}"
            }

        if "continue" not in data:
            break
        params.update(data["continue"])
        time.sleep(0.3)

# %%
import os
import time
import random
import requests
import pandas as pd
from urllib.parse import urlparse
from tqdm.notebook import tqdm
file_path_domain = "sources/domains.csv"
domain = read_domains(file_path_domain)
print(domain)
# Out:
# [DEBUG] Reading domains from: sources/domains.csv
# [DEBUG] Found 2 domains.
# ['digg.se', 'dataportal.se']

# %%
# -------------------------
# Session & helpers
# -------------------------
session = requests.Session()
session.headers.update(
    {"User-Agent": "SCB-LinkAudit/1.0 (https://www.scb.se/)"}
)

# Filter out special languages
df_wiki_lang = df_wiki[df_wiki["lang_code"] != "special"]
print("Antal Språk:", len(df_wiki_lang))

results = []

for _, row in df_wiki_lang.iterrows():
    lang = row["lang_code"]
    url = row["url"]
    lang_name = row["lang_name"]

    before = len(results)
    for d in domain:
        #print(lang, url, lang_name, d)

        for entry in fetch_exturlusage(lang, d):
            entry["domain"] = d
            entry["lang_code"] = lang
            entry["lang_name"] = lang_name
            results.append(entry)

    added = len(results) - before
    print(lang, lang_name, "-", added)
# Out:
# Antal Språk: 184
# aa Qafár af - 0
# ace Acèh - 0
# af Afrikaans - 0
# ak None - 0
# ami Pangcah - 0
# an aragonés - 0
# ast asturianu - 0
# av авар - 0
# avk Kotava - 0
# ay Aymar aru - 0
# bar Boarisch - 0
# bbc Batak Toba - 0
# bcl Bikol Central - 0
# bi Bislama - 0
# bm bamanankan - 0
# bo བོད་ཡིག - 0
# br brezhoneg - 0
# bs bosanski - 0
# btm Batak Mandailing - 0
# bug Basa Ugi - 0
# bxr буряад - 0
# cbk-zam Chavacano de Zamboanga - 0
# cdo 閩東語 / Mìng-dĕ̤ng-ngṳ̄ - 0
# ceb Cebuano - 0
# ch Chamoru - 0
# cho Chahta anumpa - 0
# chr ᏣᎳᎩ - 0
# co corsu - 0
# cr Nēhiyawēwin / ᓀᐦᐃᔭᐍᐏᐣ - 0
# csb kaszëbsczi - 0
# da dansk - 1
# de Deutsch - 0
# din Thuɔŋjäŋ - 0
# diq Zazaki - 0
# dtp Kadazandusun - 0
# dz ཇོང་ཁ - 0
# ee eʋegbe - 0
# eml emiliàn e rumagnòl - 0
# en English - 1
# es español - 0
# eu euskara - 0
# fat mfantse - 0
# ff Fulfulde - 0
# fi suomi - 0
# fj Na Vosa Vakaviti - 0
# fo føroyskt - 0
# frr Nordfriisk - 0
# gl galego - 0
# glk گیلکی - 0
# gor Bahasa Hulontalo - 0
# got 𐌲𐌿𐍄𐌹𐍃𐌺 - 0
# gpe Ghanaian Pidgin - 0
# [WARN] gsw: JSON decode failed
# [WARN] gsw: JSON decode failed
# gsw Alemannisch - 0
# guw gungbe - 0
# gv Gaelg - 0
# ha Hausa - 0
# hak 客家語 / Hak-kâ-ngî - 0
# haw Hawaiʻi - 0
# hif Fiji Hindi - 0
# ho Hiri Motu - 0
# hz Otsiherero - 0
# ia interlingua - 0
# iba Jaku Iban - 0
# id Bahasa Indonesia - 0
# ie Interlingue - 0
# ig Igbo - 0
# ii ꆇꉙ - 0
# ik Iñupiatun - 0
# ilo Ilokano - 0
# is íslenska - 0
# it italiano - 0
# ja 日本語 - 0
# jbo la .lojban. - 0
# kaa Qaraqalpaqsha - 0
# kab Taqbaylit - 0
# kcg Tyap - 0
# kg Kongo - 0
# ki Gĩkũyũ - 0
# kj Kwanyama - 0
# kl kalaallisut - 0
# knc Yerwa Kanuri - 0
# kr kanuri - 0
# ksh Ripoarisch - 0
# kv коми - 0
# kw kernowek - 0
# lb Lëtzebuergesch - 0
# lg Luganda - 0
# li Limburgs - 0
# lij Ligure - 0
# lld Ladin - 0
# lmo lombard - 0
# ln lingála - 0
# mad Madhurâ - 0
# map-bms Basa Banyumasan - 0
# mg Malagasy - 0
# mh Ebon - 0
# mi Māori - 0
# min Minangkabau - 0
# ms Bahasa Melayu - 0
# mus Mvskoke - 0
# na Dorerin Naoero - 0
# nan 閩南語 / Bân-lâm-gí - 0
# nap Napulitano - 0
# nds Plattdüütsch - 0
# nds-nl Nedersaksies - 0
# new नेपाल भाषा - 0
# ng Oshiwambo - 0
# nia Li Niha - 0
# nl Nederlands - 0
# nn norsk nynorsk - 0
# no norsk - 4
# nov Novial - 0
# nrm Nouormand - 0
# nso Sesotho sa Leboa - 0
# nup Nupe - 0
# nv Diné bizaad - 0
# ny Chi-Chewa - 0
# om Oromoo - 0
# pag Pangasinan - 0
# pam Kapampangan - 0
# pap Papiamentu - 0
# pcd Picard - 0
# pcm Naijá - 0
# pdc Deitsch - 0
# pfl Pälzisch - 0
# pi पालि - 0
# pih Norfuk / Pitkern - 0
# pl polski - 0
# pms Piemontèis - 0
# pwn pinayuanan - 0
# qu Runa Simi - 0
# rm rumantsch - 0
# rn ikirundi - 0
# ro română - 0
# roa-tara tarandíne - 0
# [WARN] rup: JSON decode failed
# [WARN] rup: JSON decode failed
# rup armãneashti - 0
# rw Ikinyarwanda - 0
# sc sardu - 0
# scn sicilianu - 0
# sco Scots - 0
# se davvisámegiella - 0
# sg Sängö - 0
# sgs žemaitėška - 0
# shi Taclḥit - 0
# simple Simple English - 0
# sm Gagana Samoa - 0
# smn anarâškielâ - 0
# sn chiShona - 0
# so Soomaaliga - 0
# sq shqip - 0
# srn Sranantongo - 0
# ss SiSwati - 0
# st Sesotho - 0
# stq Seeltersk - 0
# su Sunda - 0
# sv svenska - 61
# sw Kiswahili - 0
# szl ślůnski - 0
# tet tetun - 0
# tl Tagalog - 0
# tn Setswana - 0
# to lea faka-Tonga - 0
# tpi Tok Pisin - 0
# ts Xitsonga - 0
# tt татарча / tatarça - 0
# tum chiTumbuka - 0
# tw Twi - 0
# ty reo tahiti - 0
# ug ئۇيغۇرچە / Uyghurche - 0
# ve Tshivenda - 0
# vec vèneto - 0
# vi Tiếng Việt - 0
# vls West-Vlams - 0
# vro võro - 0
# wa walon - 0
# war Winaray - 0
# wo Wolof - 0
# xal хальмг - 0
# xh isiXhosa - 0
# yo Yorùbá - 0
# za Vahcuengh - 0
# zea Zeêuws - 0
# zh 中文 - 0
# zu isiZulu - 0

# %%
domain
# Out:
# ['digg.se', 'dataportal.se']

# %%
df_digg = pd.DataFrame(results)

# %%
len(df_digg)
# Out:
# 67

# %%
df_digg
# Out:
#    lang                                     page_title  \
# 0    da                                   Registerdata
# 1    en             List of open government data sites
# 2    no            Myndigheten för digital förvaltning
# 3    no  Diskusjon:Myndigheten för digital förvaltning
# 4    no            Myndigheten för digital förvaltning
# ..  ...                                            ...
# 62   sv                                           Umeå
# 63   sv                  Användare:Adamhr37/sandlåda 2
# 64   sv                                Ronneby Airport
# 65   sv                                   Dala Airport
# 66   sv                            Wikipedia:Bybrunnen
#
#                                                   url  \
# 0   https://www.digg.se/ledning-och-samordning/ena...
# 1                       https://www.dataportal.se/en/
# 2          https://www.digg.se/om-oss/sa-har-styrs-vi
# 3          https://www.digg.se/om-oss/sa-har-styrs-vi
# 4                                https://www.digg.se/
# ..                                                ...
# 62        https://www.dataportal.se/datasets/43_56901
# 63        https://www.dataportal.se/datasets/272_2057
# 64        https://www.dataportal.se/datasets/272_2057
# 65        https://www.dataportal.se/datasets/272_2057
# 66  https://community.dataportal.se/topic/1069/com...
#
#                                             wiki_link         domain  \
# 0          https://da.wikipedia.org/wiki/Registerdata        digg.se
# 1   https://en.wikipedia.org/wiki/List_of_open_gov...  dataportal.se
# 2   https://no.wikipedia.org/wiki/Myndigheten_för_...        digg.se
# 3   https://no.wikipedia.org/wiki/Diskusjon:Myndig...        digg.se
# 4   https://no.wikipedia.org/wiki/Myndigheten_för_...        digg.se
# ..                                                ...            ...
# 62                 https://sv.wikipedia.org/wiki/Umeå  dataportal.se
# 63  https://sv.wikipedia.org/wiki/Användare:Adamhr...  dataportal.se
# 64      https://sv.wikipedia.org/wiki/Ronneby_Airport  dataportal.se
# 65         https://sv.wikipedia.org/wiki/Dala_Airport  dataportal.se
# 66  https://sv.wikipedia.org/wiki/Wikipedia:Bybrunnen  dataportal.se
#
#    lang_code lang_name
# 0         da     dansk
# 1         en   English
# 2         no     norsk
# 3         no     norsk
# 4         no     norsk
# ..       ...       ...
# 62        sv   svenska
# 63        sv   svenska
# 64        sv   svenska
# 65        sv   svenska
# 66        sv   svenska
#
# [67 rows x 7 columns]

# %%
import pandas as pd

# --- Stats ---
total_links = len(df_digg)
total_unique_links = df_digg['url'].nunique()
num_languages = df_digg['lang'].nunique()
langs_sorted = df_digg['lang'].value_counts()

print("Total links:", total_links)
print("Total unique links:", total_unique_links)
print("Number of languages:", num_languages)
print("\nLanguages with most links:")
print(langs_sorted.to_string())
# Out:
# Total links: 67
# Total unique links: 52
# Number of languages: 4
#
# Languages with most links:
# lang
# sv    61
# no     4
# da     1
# en     1

# %%
from urllib.parse import urlparse
import pandas as pd

# Extract domain
df_digg['domain'] = df_digg['url'].apply(lambda u: urlparse(u).netloc)

# Count links grouped by domain
links_per_domain = df_digg['domain'].value_counts()

print("Links per domain:")
print(links_per_domain.to_string())
# Out:
# Links per domain:
# domain
# www.digg.se                32
# community.dataportal.se    26
# www.dataportal.se           9

# %%
from datetime import date
import os

# Sätt datum
today = date.today().strftime("%Y_%m_%d")

# Se till att katalogen finns
os.makedirs("results", exist_ok=True)

# Bygg filnamn
outfile = f"results/links_digg_v2_{today}.csv"

# Exportera
df_digg.to_csv(outfile, index=False, encoding="utf-8")

print(f"[OK] Exported {len(df_digg)} rows to {outfile}")
# Out:
# [OK] Exported 67 rows to results/links_digg_v2_2025_11_29.csv

# %%
from pathlib import Path
from datetime import date, datetime
import pandas as pd

def save_sortable_html_df_digg(df, out_dir="results"):
    out_dir = Path(out_dir)
    out_dir.mkdir(exist_ok=True)

    today = date.today().strftime("%Y_%m_%d")
    rerun_ts = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    out_path = out_dir / f"links_digg_{today}.html"

    # Gör länkar klickbara
    df = df.copy()
    if "wiki_link" in df.columns:
        df["wiki_link"] = df["wiki_link"].apply(
            lambda x: f'<a href="{x}" target="_blank">{x}</a>' if pd.notna(x) else ""
        )
    if "url" in df.columns:
        df["url"] = df["url"].apply(
            lambda x: f'<a href="{x}" target="_blank">{x}</a>' if pd.notna(x) else ""
        )

    html_table = df.to_html(
        classes="pivot",
        border=0,
        escape=False,
        index=False
    )

    css = """
    <style>
      body {
        font-family: Arial, sans-serif;
        margin: 20px;
      }
      table.pivot {
        border-collapse: collapse;
        width: 100%;
        font-size: 12px;
      }
      table.pivot th, table.pivot td {
        border: 1px solid #999;
        padding: 6px 8px;
        text-align: left;
        vertical-align: top;
        white-space: normal;
      }
      table.pivot th {
        cursor: pointer;
        background: #f2f2f2;
      }
      table.pivot th:hover {
        background: #e2e2e2;
      }
    </style>
    """

    js = """
    <script>
    document.addEventListener('DOMContentLoaded', () => {
        document.querySelectorAll("table.pivot th").forEach((header, colIndex) => {
            header.addEventListener("click", () => {
                const table = header.closest("table");
                const tbody = table.querySelector("tbody");
                const rows = Array.from(tbody.querySelectorAll("tr"));
                const asc = !header.classList.contains("sorted-asc");

                rows.sort((a, b) => {
                    const A = a.children[colIndex].innerText.trim();
                    const B = b.children[colIndex].innerText.trim();

                    const numA = parseFloat(A.replace(",", ".")) || null;
                    const numB = parseFloat(B.replace(",", ".")) || null;

                    if (numA !== null && numB !== null) {
                        return asc ? numA - numB : numB - numA;
                    }
                    return asc ? A.localeCompare(B) : B.localeCompare(A);
                });

                table.querySelectorAll("th").forEach(th =>
                    th.classList.remove("sorted-asc","sorted-desc")
                );
                header.classList.add(asc ? "sorted-asc" : "sorted-desc");

                rows.forEach(row => tbody.appendChild(row));
            });
        });
    });
    </script>
    """

    html = f"""
    <html>
    <head>
      <meta charset="utf-8">
      <title>DIGG links in Wikipedia</title>
      {css}
    </head>
    <body>
      <h1>Wikipedia → DIGG</h1>
      <p>Sorterbar tabell. Klicka på kolumnrubriker för sortering.</p>
      <p><strong>Rerun:</strong> {rerun_ts}</p>
      <p>
        <strong>Issue:</strong>
        <a href="https://github.com/salgo60/DIGG-skuggbacklog/issues/1467" target="_blank">
          #1467
        </a>
      </p>
      {html_table}
      {js}
    </body>
    </html>
    """

    out_path.write_text(html, encoding="utf-8")
    print(f"✅ HTML skapad: {out_path}")

# %%
save_sortable_html_df_digg(df_digg)
# Out:
# ✅ HTML skapad: results/links_digg_2025_11_29.html
